# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('../final Fake News Detection Survey.csv', index_col=0)

# %%
del df['I have read and understand the above and consent to participate in this study. My consent is not a waiver of any legal rights. Furthermore, I understand that I will be able to keep a copy of this consent form for my records.']

# %%
df.head()
# Out:
#                           What is your age?  \
# Timestamp
# 2020/03/11 4:21:25 pm GMT             18-24
# 2020/03/11 4:44:30 pm GMT             18-24
# 2020/03/11 4:55:13 pm GMT             18-24
# 2020/03/11 5:05:18 pm GMT             18-24
# 2020/03/11 5:10:24 pm GMT             30-39
#
#                           To which gender identity do you most identify?  \
# Timestamp
# 2020/03/11 4:21:25 pm GMT                                         Female
# 2020/03/11 4:44:30 pm GMT                                           Male
# 2020/03/11 4:55:13 pm GMT                                           Male
# 2020/03/11 5:05:18 pm GMT                                         Female
# 2020/03/11 5:10:24 pm GMT                                      nonbinary
#
#                           What is your current occupation?  \
# Timestamp
# 2020/03/11 4:21:25 pm GMT                          Student
# 2020/03/11 4:44:30 pm GMT                          Student
# ...

# %%
df2 = pd.DataFrame({'age': df['What is your age?']})

# %%
df2 = df2[df2['age'].notna()]
plot = df.plot.pie(y=df2.age, figsize=(5, 5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-5e09268d8fb4> in <module>
#       1 df2 = df2[df2['age'].notna()]
# ----> 2 plot = df.plot.pie(y=df2.age, figsize=(5, 5))
#
# D:\Anaconda\lib\site-packages\pandas\plotting\_core.py in pie(self, **kwargs)
#    1416         ):
#    1417             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1418         return self(kind="pie", **kwargs)
#    1419
#    1420     def scatter(self, x, y, s=None, c=None, **kwargs):
#
# D:\Anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     803                         y = data.columns[y]
#     804                     # converted to series actually. copy to not modify
# --> 805                     data = data[y].copy()
#     806                     data.index.name = y
# ...

# %%
sns.distplot(df['What is your age?'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-c753ac2cde55> in <module>
# ----> 1 sns.distplot(df['What is your age?'])
#       2 plt.show()
#
# D:\Anaconda\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     196             line, = ax.plot(0, a.mean())
#     197         else:
# --> 198             line, = ax.plot(a.mean(), 0)
#     199         color = line.get_color()
#     200         line.remove()
#
# D:\Anaconda\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# ...

# %%
# Count Plot (a.k.a. Bar Plot)
sns.countplot(x='Type 1', data=df)
 
# Rotate x-labels
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-e35a3d26b343> in <module>
#       1 # Count Plot (a.k.a. Bar Plot)
# ----> 2 sns.countplot(x='Type 1', data=df)
#       3
#       4 # Rotate x-labels
#       5 plt.xticks(rotation=90)
#
# D:\Anaconda\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# D:\Anaconda\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...
